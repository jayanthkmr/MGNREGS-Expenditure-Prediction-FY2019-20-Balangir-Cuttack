# %% [markdown]
# ## Assembly constituency wise expenditure on MGNREGS in Cuttack and Balangir district  of Orissa in FY2019-20 through aggregation of village level data

# %%
import sys
# !{sys.executable} -m pip install openpyxl numpy pandas scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: openpyxl in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (3.0.7)
# Requirement already satisfied: numpy in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (1.20.2)
# Requirement already satisfied: pandas in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (1.2.4)
# Requirement already satisfied: scikit-learn in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (0.24.1)
# Requirement already satisfied: matplotlib in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (3.4.1)
# Requirement already satisfied: seaborn in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: six in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: et-xmlfile in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from scikit-learn) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/Cellar/jupyterlab/3.0.13/libexec/lib/python3.9/site-packages (from scikit-learn) (1.0.1)

# %%
import math
import pandas as pd
import numpy as np
import itertools
import openpyxl 
import seaborn as sns
from openpyxl import load_workbook

import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('bmh')

# %% [markdown]
# ## Loading district level data file
#
# [Cumulative district-wise data for Orissa](data/All_AC_Census.xlsx)

# %%
district_level_file = "data/All_AC_Census.xlsx"
wb = load_workbook(filename=district_level_file, data_only=True)
ws = wb['Districts']

# %%
data = ws.values
cols = next(data)[:]
data = list(data)
#idx = [r[0] for r in data]
#data = (itertools.islice(r, 1, None) for r in data)

# %% [markdown]
# ## Data Fields
#
# The data file contains the following columns.
# 1. **District** is the name of the district given in the provided [document](data/Odisha_MGNREGS_2019-20.xlsx)
# 2. **District_Name** is the corresponding names of the districts as mentioned in Census of India, 2011
# 3. **Expenditure** is district-wise expenditure on MGNREGS in the year 2019-20
# 4. **Area_T** is the total area of the district as per the census of India, 2011 handbook of the state.
# 5. **Area_R** is the total rural area of the district as per the census of India, 2011 handbook of the state.
# 6. **No_HH** is the total no. of households in the rural part of the district.
# 7. **TOT_P** is the total population in the rual area.
# 8. **TOT_WORK_AGE_POP** is 0.664 x TOT_P
# 9. **P_ILL** is the number of rural illiterate population in the district.
# 10. **TOT_WORK_P** is the total number of rural worker population i.e. no. of individuals who worked between 0 to 12 months in the reference year. It is the sum of Main Workers (who worked more than 6 months) and Marginal Worker (who worked less than 6 months).
# 11. **NON_WORK_P** is the total number of rural non worker population i.e. no. of individuals who didn't work in the reference year.
# 12. **Elligible_NON_WORK** is TOT_WORK_AGE_POP - TOT_WORK_P
# 13. **MARGWORK_P** is the number of rural marginal worker population i.e. no. of individuals who worked between 0 to 6 months in the reference year.

# %%
print(', '.join(cols))
# Out:
# District, District_Name, Expenditure, Area_T, Area_R, No_HH, TOT_P, TOT_WORK_AGE_POP, P_ILL, TOT_WORK_P, NON_WORK_P, Elligible_NON_WORK, MARGWORK_P

# %%
dist_df = pd.DataFrame(data, columns=cols).infer_objects()

# %%
dist_df
# Out:
#           District    District_Name  Expenditure  Area_T    Area_R   No_HH  \
# 0            ANGUL         Anugul        4738.38    6375   6198.12  249733
# 1        BALESHWAR        Baleshwar      7689.49    3806   3675.32  477434
# 2          BARGARH          Bargarh      8666.33    5837   5759.09  336130
# 3          BHADRAK          Bhadrak      4108.08    2505   2388.57  270791
# 4         BOLANGIR         Balangir     14970.17    6575   6474.29  369273
# 5            BOUDH            Baudh      3771.62    3098   3077.28  102402
# 6          CUTTACK          Cuttack      5089.70    3932   3703.07  429454
# 7          DEOGARH         Debagarh      3386.36    2940   2915.87   70058
# 8        DHENKANAL        Dhenkanal      9623.83    4452   4383.82  253446
# 9         GAJAPATI         Gajapati      6327.98    4325   4287.95  112365
# 10          GANJAM           Ganjam     29142.19    8206   7846.32  596062
# 11  JAGATSINGHAPUR  Jagatsinghapur       2081.10    1668   1620.58  233626
# 12          JAJPUR        Jajapur        5800.28    2899   2807.08  378645
# 13      JHARSUGUDA       Jharsuguda      3358.73    2114   1955.41   84287
# 14       KALAHANDI        Kalahandi     12073.21    7920   7865.31  373304
# 15       KANDHAMAL        Kandhamal     11093.89    8021   7969.26  155256
# 16      KENDRAPARA      Kendrapara       5440.80    2644   2630.69  305868
# 17       KENDUJHAR        Kendujhar     14760.01    8303   8101.03  348448
# 18         KHORDHA         Khordha       2862.56    2813   2530.41  247304
# 19         KORAPUT          Koraput     16789.15    8807   8635.29  282783
# 20      MALKANGIRI     Malkangiri        4559.42    5791   5766.32  126225
# 21      MAYURBHANJ       Mayurbhanj     37590.17   10418  10309.93  542726
# 22    NABARANGAPUR    Nabarangapur      14694.33    5291   5218.69  253208
# 23        NAYAGARH       Nayagarh        5596.71    3890   3835.36  210850
# 24         NUAPADA          Nuapada      5836.25    3852   3816.77  144299
# 25            PURI             Puri      5454.14    3479   3391.09  313188
# 26        RAYAGADA       Rayagada       12618.64    7073   7004.34  191568
# 27       SAMBALPUR        Sambalpur      4790.50    6624   6467.75  179411
# 28         SONEPUR       Subarnapur      4423.18    2337   2284.21  139346
# 29      SUNDARGARH       Sundargarh     16370.73    9712   9436.12  312497
#
#       TOT_P  TOT_WORK_AGE_POP    P_ILL  TOT_WORK_P  NON_WORK_P  \
# 0   1067275        708670.600   358206      455627      611648
# 1   2067236       1372644.704   636895      847171     1220065
# 2   1331145        883880.280   461973      706885      624260
# 3   1320499        876811.336   355786      411154      909345
# 4   1451616        963873.024   670959      653289      798327
# 5    420738        279370.032   165022      212323      208415
# 6   1888423       1253912.872   480445      683899     1204524
# 7    290130        192646.320   108830      157390      132740
# 8   1075305        714002.520   339782      398386      676919
# 9    507151        336748.264   293991      267265      239886
# 10  2761030       1833323.920  1125880     1231922     1529108
# 11  1020991        677938.024   222789      364377      656614
# 12  1692095       1123551.080   503612      511605     1180490
# 13   348340        231297.760   113378      169104      179236
# 14  1454882        966041.648   741120      709276      745606
# 15   660831        438791.784   316938      329677      331154
# 16  1356827        900933.128   333342      439698      917129
# 17  1548674       1028319.536   667985      682446      866228
# 18  1167357        775125.048   307677      399642      767715
# 19  1153478        765909.392   749053      610613      542865
# 20   563664        374272.896   350783      291472      272192
# 21  2326842       1545023.088  1106414     1156323     1170519
# 22  1133321        752525.144   722786      577172      556149
# 23   883051        586345.864   257706      318229      564822
# 24   576328        382681.792   300464      292882      283446
# 25  1433800        952043.200   351598      527927      905873
# 26   820945        545107.480   515187      413699      407246
# 27   733006        486715.984   262109      390542      342464
# 28   560242        372000.688   198744      268217      292025
# 29  1355340        899945.760   573193      625502      729838
#
#     Elligible_NON_WORK  MARGWORK_P
# 0           253043.600      198171
# 1           525473.704      302716
# 2           176995.280      280109
# 3           465657.336      128740
# 4           310584.024      307264
# 5            67047.032       94667
# 6           570013.872      205250
# 7            35256.320       80486
# 8           315616.520      152607
# 9            69483.264      118144
# 10          601401.920      555034
# 11          313561.024      109149
# 12          611946.080      139062
# 13           62193.760       65684
# 14          256765.648      367994
# 15          109114.784      183842
# 16          461235.128      140509
# 17          345873.536      313494
# 18          375483.048      108017
# 19          155296.392      287580
# 20           82800.896      128255
# 21          388700.088      662964
# 22          175353.144      322672
# 23          268116.864      110228
# 24           89799.792      151261
# 25          424116.200      161345
# 26          131408.480      229832
# 27           96173.984      151753
# 28          103783.688      113048
# 29          274443.760      309890

# %% [markdown]
# ## Expenditure map across districts in Orissa

# %% [markdown]
# ![Orissa District-wise Expenditure](maps/Orissa_District.jpeg)

# %% [markdown]
# ## Feature engineering
# 1. **AreaR/AreaT** is the ratio of rural area and total area. It is an important variable as MGNREGS is a scheme for rural employment and therefore the expenditure on the scheme is positively related to rural area in each district.
# 2. **MarWkP/TotWkP** is the ratio of total marginal workers and total work population. Total marginal worker is the number of individuals who worked less than 6 months in the reference period. Therefore, the the higer the number of marginal worker in a district, more will be the expenditure on MGNREGS.
# 3. **ElgNonWkP/TotWkAgP** is the ratio of total eligible non workers and total work age population. Total non worker is the number of individuals who didn't work in the previous year. However it also includes individuals who are not eligible to work. Therefore number of eligible non workers and total work age population was calculated. The higher the ratio, higher is the expenditure on the scheme as there are more individuals in need of employment.
# 4. **IllP/TotP** is the ratio of illiterate population and total population. This ratio is crucial as expenditure on the scheme will increase if the number of illiterate people is high as it has been taken as a proxy to skills and therefore, need for employment under MGNREGA.

# %%
dist_df['AreaR/AreaT']= dist_df['Area_R']/dist_df['Area_T']

# %%
dist_df['MarWkP/TotWkP']= dist_df['MARGWORK_P']/dist_df['TOT_WORK_P']

# %%
dist_df['ElgNonWkP/TotWkAgP']= dist_df['Elligible_NON_WORK']/dist_df['TOT_WORK_AGE_POP']

# %%
dist_df['IllP/TotP']= dist_df['P_ILL']/dist_df['TOT_P']

# %%
dist_df
# Out:
#           District    District_Name  Expenditure  Area_T    Area_R   No_HH  \
# 0            ANGUL         Anugul        4738.38    6375   6198.12  249733
# 1        BALESHWAR        Baleshwar      7689.49    3806   3675.32  477434
# 2          BARGARH          Bargarh      8666.33    5837   5759.09  336130
# 3          BHADRAK          Bhadrak      4108.08    2505   2388.57  270791
# 4         BOLANGIR         Balangir     14970.17    6575   6474.29  369273
# 5            BOUDH            Baudh      3771.62    3098   3077.28  102402
# 6          CUTTACK          Cuttack      5089.70    3932   3703.07  429454
# 7          DEOGARH         Debagarh      3386.36    2940   2915.87   70058
# 8        DHENKANAL        Dhenkanal      9623.83    4452   4383.82  253446
# 9         GAJAPATI         Gajapati      6327.98    4325   4287.95  112365
# 10          GANJAM           Ganjam     29142.19    8206   7846.32  596062
# 11  JAGATSINGHAPUR  Jagatsinghapur       2081.10    1668   1620.58  233626
# 12          JAJPUR        Jajapur        5800.28    2899   2807.08  378645
# 13      JHARSUGUDA       Jharsuguda      3358.73    2114   1955.41   84287
# 14       KALAHANDI        Kalahandi     12073.21    7920   7865.31  373304
# 15       KANDHAMAL        Kandhamal     11093.89    8021   7969.26  155256
# 16      KENDRAPARA      Kendrapara       5440.80    2644   2630.69  305868
# 17       KENDUJHAR        Kendujhar     14760.01    8303   8101.03  348448
# 18         KHORDHA         Khordha       2862.56    2813   2530.41  247304
# 19         KORAPUT          Koraput     16789.15    8807   8635.29  282783
# 20      MALKANGIRI     Malkangiri        4559.42    5791   5766.32  126225
# 21      MAYURBHANJ       Mayurbhanj     37590.17   10418  10309.93  542726
# 22    NABARANGAPUR    Nabarangapur      14694.33    5291   5218.69  253208
# 23        NAYAGARH       Nayagarh        5596.71    3890   3835.36  210850
# 24         NUAPADA          Nuapada      5836.25    3852   3816.77  144299
# 25            PURI             Puri      5454.14    3479   3391.09  313188
# 26        RAYAGADA       Rayagada       12618.64    7073   7004.34  191568
# 27       SAMBALPUR        Sambalpur      4790.50    6624   6467.75  179411
# 28         SONEPUR       Subarnapur      4423.18    2337   2284.21  139346
# 29      SUNDARGARH       Sundargarh     16370.73    9712   9436.12  312497
#
#       TOT_P  TOT_WORK_AGE_POP    P_ILL  TOT_WORK_P  NON_WORK_P  \
# 0   1067275        708670.600   358206      455627      611648
# 1   2067236       1372644.704   636895      847171     1220065
# 2   1331145        883880.280   461973      706885      624260
# 3   1320499        876811.336   355786      411154      909345
# 4   1451616        963873.024   670959      653289      798327
# 5    420738        279370.032   165022      212323      208415
# 6   1888423       1253912.872   480445      683899     1204524
# 7    290130        192646.320   108830      157390      132740
# 8   1075305        714002.520   339782      398386      676919
# 9    507151        336748.264   293991      267265      239886
# 10  2761030       1833323.920  1125880     1231922     1529108
# 11  1020991        677938.024   222789      364377      656614
# 12  1692095       1123551.080   503612      511605     1180490
# 13   348340        231297.760   113378      169104      179236
# 14  1454882        966041.648   741120      709276      745606
# 15   660831        438791.784   316938      329677      331154
# 16  1356827        900933.128   333342      439698      917129
# 17  1548674       1028319.536   667985      682446      866228
# 18  1167357        775125.048   307677      399642      767715
# 19  1153478        765909.392   749053      610613      542865
# 20   563664        374272.896   350783      291472      272192
# 21  2326842       1545023.088  1106414     1156323     1170519
# 22  1133321        752525.144   722786      577172      556149
# 23   883051        586345.864   257706      318229      564822
# 24   576328        382681.792   300464      292882      283446
# 25  1433800        952043.200   351598      527927      905873
# 26   820945        545107.480   515187      413699      407246
# 27   733006        486715.984   262109      390542      342464
# 28   560242        372000.688   198744      268217      292025
# 29  1355340        899945.760   573193      625502      729838
#
#     Elligible_NON_WORK  MARGWORK_P  AreaR/AreaT  MarWkP/TotWkP  \
# 0           253043.600      198171     0.972254       0.434941
# 1           525473.704      302716     0.965665       0.357326
# 2           176995.280      280109     0.986652       0.396258
# 3           465657.336      128740     0.953521       0.313119
# 4           310584.024      307264     0.984683       0.470334
# 5            67047.032       94667     0.993312       0.445863
# 6           570013.872      205250     0.941778       0.300117
# 7            35256.320       80486     0.991793       0.511379
# 8           315616.520      152607     0.984686       0.383063
# 9            69483.264      118144     0.991434       0.442048
# 10          601401.920      555034     0.956169       0.450543
# 11          313561.024      109149     0.971571       0.299550
# 12          611946.080      139062     0.968293       0.271815
# 13           62193.760       65684     0.924981       0.388424
# 14          256765.648      367994     0.993095       0.518830
# 15          109114.784      183842     0.993549       0.557643
# 16          461235.128      140509     0.994966       0.319558
# 17          345873.536      313494     0.975675       0.459368
# 18          375483.048      108017     0.899541       0.270284
# 19          155296.392      287580     0.980503       0.470969
# 20           82800.896      128255     0.995738       0.440025
# 21          388700.088      662964     0.989627       0.573338
# 22          175353.144      322672     0.986333       0.559057
# 23          268116.864      110228     0.985954       0.346379
# 24           89799.792      151261     0.990854       0.516457
# 25          424116.200      161345     0.974731       0.305620
# 26          131408.480      229832     0.990293       0.555554
# 27           96173.984      151753     0.976412       0.388570
# 28          103783.688      113048     0.977411       0.421480
# 29          274443.760      309890     0.971594       0.495426
#
#     ElgNonWkP/TotWkAgP  IllP/TotP
# 0             0.357068   0.335627
# 1             0.382818   0.308090
# 2             0.200248   0.347049
# 3             0.531080   0.269433
# 4             0.322225   0.462215
# 5             0.239994   0.392220
# 6             0.454588   0.254416
# 7             0.183011   0.375108
# 8             0.442038   0.315987
# 9             0.206336   0.579691
# 10            0.328039   0.407775
# 11            0.462522   0.218209
# 12            0.544654   0.297626
# 13            0.268890   0.325481
# 14            0.265791   0.509402
# 15            0.248671   0.479605
# 16            0.511953   0.245678
# 17            0.336348   0.431327
# 18            0.484416   0.263567
# 19            0.202761   0.649386
# 20            0.221231   0.622326
# 21            0.251582   0.475500
# 22            0.233020   0.637759
# 23            0.457267   0.291836
# 24            0.234659   0.521342
# 25            0.445480   0.245221
# 26            0.241069   0.627554
# 27            0.197598   0.357581
# 28            0.278988   0.354747
# 29            0.304956   0.422915

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_num = dist_df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#    Expenditure  Area_T   Area_R   No_HH    TOT_P  TOT_WORK_AGE_POP   P_ILL  \
# 0      4738.38    6375  6198.12  249733  1067275        708670.600  358206
# 1      7689.49    3806  3675.32  477434  2067236       1372644.704  636895
# 2      8666.33    5837  5759.09  336130  1331145        883880.280  461973
# 3      4108.08    2505  2388.57  270791  1320499        876811.336  355786
# 4     14970.17    6575  6474.29  369273  1451616        963873.024  670959
#
#    TOT_WORK_P  NON_WORK_P  Elligible_NON_WORK  MARGWORK_P  AreaR/AreaT  \
# 0      455627      611648          253043.600      198171     0.972254
# 1      847171     1220065          525473.704      302716     0.965665
# 2      706885      624260          176995.280      280109     0.986652
# 3      411154      909345          465657.336      128740     0.953521
# 4      653289      798327          310584.024      307264     0.984683
#
#    MarWkP/TotWkP  ElgNonWkP/TotWkAgP  IllP/TotP
# 0       0.434941            0.357068   0.335627
# 1       0.357326            0.382818   0.308090
# 2       0.396258            0.200248   0.347049
# 3       0.313119            0.531080   0.269433
# 4       0.470334            0.322225   0.462215

# %%
print(dist_df['Expenditure'].describe())
# Out:
# count       30.000000
# mean      9456.931000
# std       7918.593502
# min       2081.100000
# 25%       4604.160000
# 50%       5818.265000
# 75%      12482.282500
# max      37590.170000
# Name: Expenditure, dtype: float64

# %%
plt.figure(figsize=(3, 1))
sns.displot(dist_df['Expenditure'], color='g', bins=30);

# %%
df_num.hist(figsize=(12, 15), bins=30, xlabelsize=8, ylabelsize=8);

# %%
sns.pairplot(data=df_num,
                x_vars=df_num.columns[1:],
                y_vars=['Expenditure'])

# %%
corr = df_num.corr() # We already examined SalePrice correlations
plt.figure(figsize=(12, 10))

sns.heatmap(corr, 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
X = dist_df[['AreaR/AreaT','No_HH','IllP/TotP','MarWkP/TotWkP','ElgNonWkP/TotWkAgP']]

# %%
X
# Out:
#     AreaR/AreaT   No_HH  IllP/TotP  MarWkP/TotWkP  ElgNonWkP/TotWkAgP
# 0      0.972254  249733   0.335627       0.434941            0.357068
# 1      0.965665  477434   0.308090       0.357326            0.382818
# 2      0.986652  336130   0.347049       0.396258            0.200248
# 3      0.953521  270791   0.269433       0.313119            0.531080
# 4      0.984683  369273   0.462215       0.470334            0.322225
# 5      0.993312  102402   0.392220       0.445863            0.239994
# 6      0.941778  429454   0.254416       0.300117            0.454588
# 7      0.991793   70058   0.375108       0.511379            0.183011
# 8      0.984686  253446   0.315987       0.383063            0.442038
# 9      0.991434  112365   0.579691       0.442048            0.206336
# 10     0.956169  596062   0.407775       0.450543            0.328039
# 11     0.971571  233626   0.218209       0.299550            0.462522
# 12     0.968293  378645   0.297626       0.271815            0.544654
# 13     0.924981   84287   0.325481       0.388424            0.268890
# 14     0.993095  373304   0.509402       0.518830            0.265791
# 15     0.993549  155256   0.479605       0.557643            0.248671
# 16     0.994966  305868   0.245678       0.319558            0.511953
# 17     0.975675  348448   0.431327       0.459368            0.336348
# 18     0.899541  247304   0.263567       0.270284            0.484416
# 19     0.980503  282783   0.649386       0.470969            0.202761
# 20     0.995738  126225   0.622326       0.440025            0.221231
# 21     0.989627  542726   0.475500       0.573338            0.251582
# 22     0.986333  253208   0.637759       0.559057            0.233020
# 23     0.985954  210850   0.291836       0.346379            0.457267
# 24     0.990854  144299   0.521342       0.516457            0.234659
# 25     0.974731  313188   0.245221       0.305620            0.445480
# 26     0.990293  191568   0.627554       0.555554            0.241069
# 27     0.976412  179411   0.357581       0.388570            0.197598
# 28     0.977411  139346   0.354747       0.421480            0.278988
# 29     0.971594  312497   0.422915       0.495426            0.304956

# %%
Y = (dist_df[['Expenditure']]/dist_df[['Expenditure']].sum()).values #using ratio of expenditure

# %%
Y
# Out:
# array([[0.01670161],
#        [0.02710354],
#        [0.03054666],
#        [0.01447996],
#        [0.05276613],
#        [0.01329402],
#        [0.01793993],
#        [0.01193608],
#        [0.03392161],
#        [0.02230456],
#        [0.10271898],
#        [0.00733536],
#        [0.02044455],
#        [0.01183869],
#        [0.04255507],
#        [0.03910321],
#        [0.01917747],
#        [0.05202537],
#        [0.01008981],
#        [0.05917758],
#        [0.01607082],
#        [0.13249601],
#        [0.05179386],
#        [0.01972701],
#        [0.02057133],
#        [0.01922449],
#        [0.04447757],
#        [0.01688532],
#        [0.01559061],
#        [0.05770276]])

# %% [markdown]
# ## Regression Analysis
#
# Linear regression regresses target variable over the whole range from $(-\infty, \infty)$.
# Also, expenditure for district has a higher upper bound than expenditure for AC.
# To resolve these, expenditure is scaled to domain between 0 and 1 by taking its ratio over the whole. The expenditure ratio lies between 0 and 1 and used as Y.
#
# Next, the expenditure ratio as p is transformed back to the domain of $(-\infty, \infty)$ by taking log-odds :
#
# $$ y = log(\frac{p}{1-p}) $$
#
# Note, this transforms p to the domain of $(-\infty, \infty)$ at the values of 0 and 1 respectively. Now, we can use any regression technique, since our dependant variable ranges over whole real domain. But after regression prediction, the output should be transformed back to the domain of 0 to 1 by exponentiating the log-odds:
#
# $$ p = \frac{1}{e^{-y} + 1} $$
#
# Note, this transforms y back to the domain of $(0, 1)$ at the values of $(-\infty, \infty)$ respectively.
#
# For regressing x and y, we can choose any suitable regression techniques.
# Over here, we have selected [PLS (Partial Least Square) Regression](https://en.wikipedia.org/wiki/Partial_least_squares_regression), which actually finds a Linear Regression model by projecting the dependant variable and the independant variables to a new space. We can also, use Linear Regression only.

# %%
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression

class LogitRegression(PLSRegression):

    def fit(self, x, p):
        p = np.asarray(p)
        y = np.log(p / (1 - p))
        return super().fit(x, y)

    def predict(self, x):
        y = super().predict(x)
        return 1 / (np.exp(-y) + 1)

regr = LogitRegression()
regr.fit(X, Y)
# Out:
# LogitRegression()

# %%
regr.coef_ #note the coefficient of No_HH is largest while for last term is negative
# Out:
# array([[ 0.06433795],
#        [ 0.53156461],
#        [ 0.19995576],
#        [ 0.26622207],
#        [-0.02129568]])

# %%
regr.score(X,Y) # the coefficient of determination R^2 of the prediction.
# Out:
# 0.914374109715391

# %%
yPred = regr.predict(X)

residuals = yPred[:,0]-Y[:,0]
residualsratio = abs(yPred[:,0]-Y[:,0])/Y[:,0]

fig,ax = plt.subplots(2,2, figsize=(15,10))
ax[0,0].scatter(Y[:,0], yPred[:,0], marker="o")
ax[0,0].plot(Y[:,0], Y[:,0], color="grey", linestyle="-")
ax[0,1].scatter(Y[:,0], residuals)
ax[0,0].set_title("Model")
ax[0,0].set_ylabel("Predicted Y")
ax[0,0].set_xlabel("Observed Y")
ax[0,1].set_title("Residuals")
ax[0,1].set_xlabel("Observed Y")
ax[1,0].plot(Y[:,0])
ax[1,0].plot(yPred[:,0], color="red")
ax[1,0].set_title("Y Run Chart")
ax[1,1].plot(residualsratio)
text = ax[1,1].set_title("Residuals Ratio Run Chart")

# %% [markdown]
# ## Expenditure prediction for assembly constituencies in Cuttack

# %%
district_level_file = "data/All_AC_Census.xlsx"
wb = load_workbook(filename=district_level_file, data_only=True)
ws = wb['All_AC_Cuttack']

# %%
data = ws.values
cols = next(data)[:]
data = list(data)
#idx = [r[0] for r in data]
#data = (itertools.islice(r, 1, None) for r in data)

# %% [markdown]
# ## Data Fields
#
# The data file contains the following columns.
# 1. **AC_Name** is the name of Assembly Constituency(AC) in Cuttack district.
# 2. **Area_Map** is the total area of the AC, calculated through QGIS.
# 3. **Area_Sum** is the total rural area of the AC, calculated by adding up the area of the villages that was also calculated through QGIS.
# 4. **No_HH** is the total no. of rural households in the AC, calculated by adding up the households in the villages for the respective AC. The household data for the villages was taken from Census of India, 2011.
# 5. **TOT_P** is the sum of the total population of the villages in the AC.
# 6. **TOT_WORK_AGE_POP** is 0.664 x TOT_P
# 7. **P_ILL** is the sum of illiterate population of the villages in the AC.
# 8. **TOT_WORK_P** is the sum of worker population i.e. no. of individuals who worked between 0 to 12 months in the reference year in the villages that come under the respective AC. It is the sum of Main Workers (who worked more than 6 months) and Marginal Worker (who worked less than 6 months).
# 9. **MARGWORK_P** is the sum marginal worker population i.e. no. of individuals who worked between 0 to 6 months in the reference year in the villages that come under the respective AC.
# 10. **NON_WORK_P** is the sum of non worker population i.e. no. of individuals who didn't work in the reference year in the villages that come under the respective AC.
# 11. **Elligible_NON_WORK** is TOT_WORK_AGE_POP - TOT_WORK_P

# %%
print(cols)
# Out:
# ('AC_Name', 'Area_Map', 'Area_Sum', 'No_HH', 'TOT_P', 'TOT_WORK_AGE_POP', 'P_ILL', 'TOT_WORK_P', 'MARGWORK_P', 'NON_WORK_P', 'Elligible_NON_WORK')

# %%
print(', '.join(cols))
# Out:
# AC_Name, Area_Map, Area_Sum, No_HH, TOT_P, TOT_WORK_AGE_POP, P_ILL, TOT_WORK_P, MARGWORK_P, NON_WORK_P, Elligible_NON_WORK

# %%
AC_df = pd.DataFrame(data, columns=cols).infer_objects()

# %%
AC_df
# Out:
#               AC_Name  Area_Map  Area_Sum  No_HH   TOT_P  TOT_WORK_AGE_POP  \
# 0             SALIPUR   451.984   465.033  60277  266126        176707.664
# 1            ATHAGARH   677.627   678.603  59514  270051        179313.864
# 2             MAHANGA   358.708   363.269  66039  277733        184414.712
# 3             BARAMBA  1085.153  1074.385  76582  328054        217827.856
# 4    CHOUDWAR-CUTTACK    93.853    89.862   8433   40179         26678.856
# 5    BARABATI-CUTTACK   108.246   115.774    607    2971          1972.744
# 6               BANKI   629.993   628.650  55716  243785        161873.240
# 7          NIALI (SC)   417.149   421.594  61857  271324        180159.136
# 8  CUTTACK SADAR (SC)   323.440   290.192  44233  197424        131089.536
#
#    P_ILL  TOT_WORK_P  MARGWORK_P  NON_WORK_P  Elligible_NON_WORK
# 0  66671       99322       33063      166804           77385.664
# 1  75980       99215       27452      170836           80098.864
# 2  65538       96603       28657      181130           87811.712
# 3  90351      120314       29576      207740           97513.856
# 4   9881       13503        2722       26676           13175.856
# 5    730         939          14        2032            1033.744
# 6  64754       83652       26150      160133           78221.240
# 7  64067       97381       28561      173943           82778.136
# 8  47417       71994       21446      125430           59095.536

# %% [markdown]
# ## Feature engineering
# 1. **AreaR/AreaT** is the ratio of sum of village area, calculated from Census data and total area of the AC, calculated through QGIS.
# 2. **MarWkP/TotWkP** is the ratio of total marginal workers and total work population as sum of respective data of the villages in given AC.
# 3. **ElgNonWkP/TotWkAgP** is the ratio of total eligible non workers and total work age population.
# 4. **IllP/TotP** is the ratio of illiterate opulation and total population.

# %%
AC_df['AreaR/AreaT']= AC_df['Area_Sum']/AC_df['Area_Map']

# %%
AC_df
# Out:
#               AC_Name  Area_Map  Area_Sum  No_HH   TOT_P  TOT_WORK_AGE_POP  \
# 0             SALIPUR   451.984   465.033  60277  266126        176707.664
# 1            ATHAGARH   677.627   678.603  59514  270051        179313.864
# 2             MAHANGA   358.708   363.269  66039  277733        184414.712
# 3             BARAMBA  1085.153  1074.385  76582  328054        217827.856
# 4    CHOUDWAR-CUTTACK    93.853    89.862   8433   40179         26678.856
# 5    BARABATI-CUTTACK   108.246   115.774    607    2971          1972.744
# 6               BANKI   629.993   628.650  55716  243785        161873.240
# 7          NIALI (SC)   417.149   421.594  61857  271324        180159.136
# 8  CUTTACK SADAR (SC)   323.440   290.192  44233  197424        131089.536
#
#    P_ILL  TOT_WORK_P  MARGWORK_P  NON_WORK_P  Elligible_NON_WORK  AreaR/AreaT
# 0  66671       99322       33063      166804           77385.664     1.028870
# 1  75980       99215       27452      170836           80098.864     1.001440
# 2  65538       96603       28657      181130           87811.712     1.012715
# 3  90351      120314       29576      207740           97513.856     0.990077
# 4   9881       13503        2722       26676           13175.856     0.957476
# 5    730         939          14        2032            1033.744     1.069545
# 6  64754       83652       26150      160133           78221.240     0.997868
# 7  64067       97381       28561      173943           82778.136     1.010656
# 8  47417       71994       21446      125430           59095.536     0.897205

# %%
AC_df['MarWkP/TotWkP']= AC_df['MARGWORK_P']/AC_df['TOT_WORK_P']

# %%
AC_df['ElgNonWkP/TotWkAgP']= AC_df['Elligible_NON_WORK']/AC_df['TOT_WORK_AGE_POP']

# %%
AC_df['IllP/TotP']= AC_df['P_ILL']/AC_df['TOT_P']

# %%
AC_df
# Out:
#               AC_Name  Area_Map  Area_Sum  No_HH   TOT_P  TOT_WORK_AGE_POP  \
# 0             SALIPUR   451.984   465.033  60277  266126        176707.664
# 1            ATHAGARH   677.627   678.603  59514  270051        179313.864
# 2             MAHANGA   358.708   363.269  66039  277733        184414.712
# 3             BARAMBA  1085.153  1074.385  76582  328054        217827.856
# 4    CHOUDWAR-CUTTACK    93.853    89.862   8433   40179         26678.856
# 5    BARABATI-CUTTACK   108.246   115.774    607    2971          1972.744
# 6               BANKI   629.993   628.650  55716  243785        161873.240
# 7          NIALI (SC)   417.149   421.594  61857  271324        180159.136
# 8  CUTTACK SADAR (SC)   323.440   290.192  44233  197424        131089.536
#
#    P_ILL  TOT_WORK_P  MARGWORK_P  NON_WORK_P  Elligible_NON_WORK  AreaR/AreaT  \
# 0  66671       99322       33063      166804           77385.664     1.028870
# 1  75980       99215       27452      170836           80098.864     1.001440
# 2  65538       96603       28657      181130           87811.712     1.012715
# 3  90351      120314       29576      207740           97513.856     0.990077
# 4   9881       13503        2722       26676           13175.856     0.957476
# 5    730         939          14        2032            1033.744     1.069545
# 6  64754       83652       26150      160133           78221.240     0.997868
# 7  64067       97381       28561      173943           82778.136     1.010656
# 8  47417       71994       21446      125430           59095.536     0.897205
#
#    MarWkP/TotWkP  ElgNonWkP/TotWkAgP  IllP/TotP
# 0       0.332887            0.437930   0.250524
# 1       0.276692            0.446696   0.281354
# 2       0.296647            0.476164   0.235975
# 3       0.245823            0.447665   0.275415
# 4       0.201585            0.493869   0.245924
# 5       0.014909            0.524013   0.245709
# 6       0.312605            0.483225   0.265619
# 7       0.293291            0.459472   0.236127
# 8       0.297886            0.450803   0.240178

# %%
X = AC_df[['AreaR/AreaT','No_HH','IllP/TotP','MarWkP/TotWkP','ElgNonWkP/TotWkAgP']]

# %%
X.columns
# Out:
# Index(['AreaR/AreaT', 'No_HH', 'IllP/TotP', 'MarWkP/TotWkP',
#        'ElgNonWkP/TotWkAgP'],
#       dtype='object')

# %%
Y = regr.predict(X)

# %%
Y
# Out:
# array([[0.00805824],
#        [0.0066018 ],
#        [0.00688123],
#        [0.00619503],
#        [0.003581  ],
#        [0.00278853],
#        [0.00692146],
#        [0.0066847 ],
#        [0.00457253]])

# %%
Y = Y/sum(Y)

# %%
Y
# Out:
# array([[0.15412284],
#        [0.1262669 ],
#        [0.13161122],
#        [0.1184869 ],
#        [0.06849064],
#        [0.05333379],
#        [0.13238061],
#        [0.12785231],
#        [0.0874548 ]])

# %%
sum(Y)* (dist_df.loc[(dist_df['District_Name'] == 'Cuttack')]['Expenditure']).values[0] #5089.7
# Out:
# array([5089.7])

# %%
pd.concat([AC_df['AC_Name'].reset_index(), pd.DataFrame(Y * (dist_df.loc[(dist_df['District_Name'] == 'Cuttack')]['Expenditure']).values[0])], axis=1)
# Out:
#    index             AC_Name           0
# 0      0             SALIPUR  784.438994
# 1      1            ATHAGARH  642.660656
# 2      2             MAHANGA  669.861601
# 3      3             BARAMBA  603.062760
# 4      4    CHOUDWAR-CUTTACK  348.596800
# 5      5    BARABATI-CUTTACK  271.452981
# 6      6               BANKI  673.777606
# 7      7          NIALI (SC)  650.729890
# 8      8  CUTTACK SADAR (SC)  445.118713

# %% [markdown]
# ## Map of the AC-wise expenditure in Cuttack on MGNREGS (2019-20)

# %% [markdown]
# ![Cuttack AC Expenditure](maps/Map_Cuttack_AC.jpeg)

# %% [markdown]
# ## Expenditure prediction for assembly constituencies in Balangir

# %%
district_level_file = "data/All_AC_Census.xlsx"
wb = load_workbook(filename=district_level_file, data_only=True)
ws = wb['All_AC_Balangir']

# %%
data = ws.values
cols = next(data)[:]
data = list(data)
#idx = [r[0] for r in data]
#data = (itertools.islice(r, 1, None) for r in data)

# %% [markdown]
# ## Data Fields
#
# The data file contains the following columns.
# 1. **AC_Name** is the name of Assembly Constituency(AC) in Balangir district.
# 2. **Area_Map** is the total area of the AC, calculated through QGIS.
# 3. **Area_sum** is the total rural area of the AC, calculated by adding up the area of the villages that was also calculated through QGIS.
# 4. **No_HH** is the total no. of rural households in the AC, calculated by adding up the households in the villages for the respective AC. The household data for the villages was taken from Census of India, 2011.
# 5. **TOT_P** is the sum of the total population of the villages in the AC.
# 6. **TOT_WORK_AGE_POP** is 0.664 x TOT_P
# 7. **P_ILL** is the sum of illiterate population of the villages in the AC.
# 8. **TOT_WORK_P** is the sum of worker population i.e. no. of individuals who worked between 0 to 12 months in the reference year in the villages that come under the respective AC. It is the sum of Main Workers (who worked more than 6 months) and Marginal Worker (who worked less than 6 months).
# 9. **MARGWORK_P** is the sum marginal worker population i.e. no. of individuals who worked between 0 to 6 months in the reference year in the villages that come under the respective AC.
# 10. **NON_WORK_P** is the sum of non worker population i.e. no. of individuals who didn't work in the reference year in the villages that come under the respective AC.
# 11. **Elligible_NON_WORK** is TOT_WORK_AGE_POP - TOT_WORK_P

# %%
print(cols)
# Out:
# ('AC_Name', 'Area_Map', 'Area_sum', 'No_HH', 'TOT_P', 'TOT_WORK_AGE_POP', 'P_ILL', 'TOT_WORK_P', 'MARGWORK_P', 'NON_WORK_P', 'Elligible_NON_WORK')

# %%
AC_df = pd.DataFrame(data, columns=cols).infer_objects()

# %%
AC_df
# Out:
#       AC_Name   Area_Map  Area_sum  No_HH   TOT_P  TOT_WORK_AGE_POP   P_ILL  \
# 0   Loisingha  1081.3757  1079.124  76986  304840        202413.760  119016
# 1    Balangir  1053.8766  1053.644  97415  384377        255226.328  160172
# 2   Patnagarh  1987.5615  2002.185  94479  370957        246315.448  174034
# 3   Titlagarh  1439.7318  1415.216  73366  279884        185842.976  127754
# 4  Kantabanji  1470.3545  1494.079  83870  329999        219119.336  173546
#
#    TOT_WORK_P  MARGWORK_P  NON_WORK_P  Elligible_NON_WORK
# 0      134350       56895      170490           68063.760
# 1      153731       73642      230646          101495.328
# 2      176562       81830      194395           69753.448
# 3      124687       63730      155197           61155.976
# 4      154154       79578      175845           64965.336

# %% [markdown]
# ## Feature engineering
# 1. **AreaR/AreaT** is the ratio of sum of village area, calculated from Census data and total area of the AC, calculated through QGIS.
# 2. **MarWkP/TotWkP** is the ratio of total marginal workers and total work population as sum of respective data of the villages in given AC.
# 3. **ElgNonWkP/TotWkAgP** is the ratio of total eligible non workers and total work age population.
# 4. **IllP/TotP** is the ratio of illiterate opulation and total population.

# %%
AC_df['AreaR/AreaT']= AC_df['Area_sum']/AC_df['Area_Map']

# %%
AC_df['MarWkP/TotWkP']= AC_df['MARGWORK_P']/AC_df['TOT_WORK_P']

# %%
AC_df['ElgNonWkP/TotWkAgP']= AC_df['Elligible_NON_WORK']/AC_df['TOT_WORK_AGE_POP']

# %%
AC_df['IllP/TotP']= AC_df['P_ILL']/AC_df['TOT_P']

# %%
AC_df
# Out:
#       AC_Name   Area_Map  Area_sum  No_HH   TOT_P  TOT_WORK_AGE_POP   P_ILL  \
# 0   Loisingha  1081.3757  1079.124  76986  304840        202413.760  119016
# 1    Balangir  1053.8766  1053.644  97415  384377        255226.328  160172
# 2   Patnagarh  1987.5615  2002.185  94479  370957        246315.448  174034
# 3   Titlagarh  1439.7318  1415.216  73366  279884        185842.976  127754
# 4  Kantabanji  1470.3545  1494.079  83870  329999        219119.336  173546
#
#    TOT_WORK_P  MARGWORK_P  NON_WORK_P  Elligible_NON_WORK  AreaR/AreaT  \
# 0      134350       56895      170490           68063.760     0.997918
# 1      153731       73642      230646          101495.328     0.999779
# 2      176562       81830      194395           69753.448     1.007358
# 3      124687       63730      155197           61155.976     0.982972
# 4      154154       79578      175845           64965.336     1.016135
#
#    MarWkP/TotWkP  ElgNonWkP/TotWkAgP  IllP/TotP
# 0       0.423483            0.336261   0.390421
# 1       0.479032            0.397668   0.416705
# 2       0.463463            0.283187   0.469149
# 3       0.511120            0.329073   0.456453
# 4       0.516224            0.296484   0.525899

# %%
X = AC_df[['AreaR/AreaT','No_HH','IllP/TotP','MarWkP/TotWkP','ElgNonWkP/TotWkAgP']]

# %%
X.columns
# Out:
# Index(['AreaR/AreaT', 'No_HH', 'IllP/TotP', 'MarWkP/TotWkP',
#        'ElgNonWkP/TotWkAgP'],
#       dtype='object')

# %%
X
# Out:
#    AreaR/AreaT  No_HH  IllP/TotP  MarWkP/TotWkP  ElgNonWkP/TotWkAgP
# 0     0.997918  76986   0.390421       0.423483            0.336261
# 1     0.999779  97415   0.416705       0.479032            0.397668
# 2     1.007358  94479   0.469149       0.463463            0.283187
# 3     0.982972  73366   0.456453       0.511120            0.329073
# 4     1.016135  83870   0.525899       0.516224            0.296484

# %%
Y = regr.predict(X)

# %%
Y
# Out:
# array([[0.0128773 ],
#        [0.01692747],
#        [0.01808511],
#        [0.01729234],
#        [0.02246757]])

# %%
Y = Y/sum(Y)

# %%
Y
# Out:
# array([[0.14691767],
#        [0.19312622],
#        [0.20633377],
#        [0.19728896],
#        [0.25633339]])

# %%
sum(Y)* (dist_df.loc[(dist_df['District_Name'] == 'Balangir')]['Expenditure']).values[0] #14970.17
# Out:
# array([14970.17])

# %%
pd.concat([AC_df['AC_Name'].reset_index(), pd.DataFrame(Y * (dist_df.loc[(dist_df['District_Name'] == 'Balangir')]['Expenditure']).values[0])], axis=1)
# Out:
#    index     AC_Name            0
# 0      0   Loisingha  2199.382477
# 1      1    Balangir  2891.132289
# 2      2   Patnagarh  3088.851544
# 3      3   Titlagarh  2953.449204
# 4      4  Kantabanji  3837.354485

# %% [markdown]
# ## Map of the AC-wise expenditure in Balangir on MGNREGS (2019-20)
#
# >*This map is also used as an example to show the village boundaries of the villages in the respective ACs.*

# %% [markdown]
# ![Balangir AC Expenditure](maps/Map_Balangir_AC.jpeg)

# %% [markdown]
# ## *The End*
